# %% [markdown]
# # Simple Vector (Arrow) Icon for folium
#
# This package provides simple vector (arrow) icon for the [folium](https://pypi.org/project/folium/) package.
#
# The vector (arrow) icon is independent zoom level, its size does not change as zoom level changes.
# It is useful for displaying vector field.
#
# Install from PyPI:
#
# ```shell
# pip install folium_vector_icon
# ```
#
# This packages is released under MIT licence.
#
# See [](#sample-code) for example.

# %% [markdown]
# ## Module contents
#
# ```{eval-rst}
# .. automodule:: folium_vector_icon
#    :members:
#    :undoc-members:
#    :show-inheritance:
# ```

# %% [markdown]
# ## Sample Code

# %%
import math

import folium
from folium_vector_icon import VectorIcon

# %% [markdown]
# ### By length and angle

# %%
m = folium.Map(
    location=[40.78322, -73.96551],
    zoom_start=14,
    tiles='Cartodb Positron'
)

folium.Marker(
    [40.78322, -73.96551],
    icon=VectorIcon(100, 0)
).add_to(m)

folium.Marker(
    [40.78322, -73.96551],
    icon=VectorIcon(100, math.pi / 2, color="red")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72bd11179130e8760678007b0388a57b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72bd11179130e8760678007b0388a57b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72bd11179130e8760678007b0388a57b = L.map(
#                 &quot;map_72bd11179130e8760678007b0388a57b&quot;,
#                 {
#                     center: [40.78322, -73.96551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce10ea010949e24be71d3fb30d1322ad = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_ce10ea010949e24be71d3fb30d1322ad.addTo(map_72bd11179130e8760678007b0388a57b);
#
#             var marker_9f48570ed47e235cb31f8e96ad2bcd0e = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_72bd11179130e8760678007b0388a57b);
#
#
#             var div_icon_a2c3f690a341173fb674df52613681c4 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg\n  xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\n  version=\&quot;1.1\&quot;\n  viewBox=\&quot;-10 -110 21 120\&quot;\n  stroke=\&quot;black\&quot;\n  fill=\&quot;black\&quot;\n  stroke-width=\&quot;0\&quot;\n\u003e\n  \u003cpath d=\&quot;M -1 -6.123234e-17 l 2 1.224647e-16\nl 5.510911e-15 -90 l 3 1.83697e-16\nl -4 -10 l -4 10\nl 3 1.83697e-16 Z\&quot; /\u003e\n\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 110], &quot;iconSize&quot;: [21, 120]});
#             marker_9f48570ed47e235cb31f8e96ad2bcd0e.setIcon(div_icon_a2c3f690a341173fb674df52613681c4);
#
#
#             var marker_bafbd227f013ab5ab9140a47fa954da6 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_72bd11179130e8760678007b0388a57b);
#
#
#             var div_icon_25a0362a8af67d8c3b86c65a0b3767e5 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg\n  xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\n  version=\&quot;1.1\&quot;\n  viewBox=\&quot;-10 -10 120 20\&quot;\n  stroke=\&quot;red\&quot;\n  fill=\&quot;red\&quot;\n  stroke-width=\&quot;0\&quot;\n\u003e\n  \u003cpath d=\&quot;M 0 -1 l 0 2\nl 90 0 l 0 3\nl 10 -4 l -10 -4\nl 0 3 Z\&quot; /\u003e\n\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [120, 20]});
#             marker_bafbd227f013ab5ab9140a47fa954da6.setIcon(div_icon_25a0362a8af67d8c3b86c65a0b3767e5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### By components of latitude and longitude direction

# %%
m = folium.Map(
    location=[40.78322, -73.96551],
    zoom_start=14,
    tiles='Cartodb Positron'
)

folium.Marker(
    [40.78322, -73.96551],
    icon=VectorIcon.from_comp((100, 50))
).add_to(m)

folium.Marker(
    [40.78322, -73.96551],
    icon=VectorIcon.from_comp((-50, 100), color="red")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e1769694fcf01518fe5b1596ab6d353 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e1769694fcf01518fe5b1596ab6d353&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e1769694fcf01518fe5b1596ab6d353 = L.map(
#                 &quot;map_1e1769694fcf01518fe5b1596ab6d353&quot;,
#                 {
#                     center: [40.78322, -73.96551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab5ff43e96448738040cb9a8431ed322 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_ab5ff43e96448738040cb9a8431ed322.addTo(map_1e1769694fcf01518fe5b1596ab6d353);
#
#             var marker_8b4913242ec49ada3725bcf84bfebfd8 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_1e1769694fcf01518fe5b1596ab6d353);
#
#
#             var div_icon_7f4dfd51ace5d504d68d59bf8ab8abd1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg\n  xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\n  version=\&quot;1.1\&quot;\n  viewBox=\&quot;-10 -110 71 120\&quot;\n  stroke=\&quot;black\&quot;\n  fill=\&quot;black\&quot;\n  stroke-width=\&quot;0\&quot;\n\u003e\n  \u003cpath d=\&quot;M -0.8944272 -0.4472136 l 1.788854 0.8944272\nl 45.52786 -91.05573 l 2.683282 1.341641\nl 0.8944272 -10.73313 l -8.049845 7.155418\nl 2.683282 1.341641 Z\&quot; /\u003e\n\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 110], &quot;iconSize&quot;: [71, 120]});
#             marker_8b4913242ec49ada3725bcf84bfebfd8.setIcon(div_icon_7f4dfd51ace5d504d68d59bf8ab8abd1);
#
#
#             var marker_492f926042325ea9af01f821cfe8032c = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_1e1769694fcf01518fe5b1596ab6d353);
#
#
#             var div_icon_89af62a726ebb074f338645ef608c924 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg\n  xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\n  version=\&quot;1.1\&quot;\n  viewBox=\&quot;-10 -10 120 71\&quot;\n  stroke=\&quot;red\&quot;\n  fill=\&quot;red\&quot;\n  stroke-width=\&quot;0\&quot;\n\u003e\n  \u003cpath d=\&quot;M 0.4472136 -0.8944272 l -0.8944272 1.788854\nl 91.05573 45.52786 l -1.341641 2.683282\nl 10.73313 0.8944272 l -7.155418 -8.049845\nl -1.341641 2.683282 Z\&quot; /\u003e\n\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [10, 10], &quot;iconSize&quot;: [120, 71]});
#             marker_492f926042325ea9af01f821cfe8032c.setIcon(div_icon_89af62a726ebb074f338645ef608c924);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Variation of anchor

# %%
from folium_vector_icon import VectorIconHead, VectorIconBody

# %%
def marker(i: int, anchor: str, delta: float) -> folium.Marker:
    lat, lng = 40.78322, -73.96551
    return folium.Marker(
        # shif by (0.001 * i, delta) from (40.78322, -73.96551)
        [lat + 0.001 * i, lng + delta],
        icon=VectorIcon(
            # wavy visualization
            150 + 50 * math.sin(i * math.pi / 20),
            math.pi / 2,
            # rainbowing by css property "hsl"
            color=f"hsl({i * 10}deg, 100%, 50%)",
            # show border of vector
            border_color="black",
            border_width=1,
            # big head
            head=VectorIconHead(
                width=12,
                length=20
            ),
            # thin body relative to head
            body=VectorIconBody(
                width=3
            ),
            # anchor is variable
            anchor=anchor
        )
    )

# %%
m = folium.Map(
    location=[40.78322 + 0.015, -73.96551 + 0.04],
    zoom_start=14,
    tiles='Cartodb Positron'
)

for i in range(36):
    # The left is anchor at 'tail' (default)
    marker(i, anchor="tail", delta=0.0).add_to(m)

    # The left is anchor at 'haed'
    marker(i, anchor="head", delta=0.04).add_to(m)

    # The left is anchor at 'mid'
    marker(i, anchor="mid", delta=0.06).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7942542a69a2fa2326156dfed86a1de3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7942542a69a2fa2326156dfed86a1de3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7942542a69a2fa2326156dfed86a1de3 = L.map(
#                 &quot;map_7942542a69a2fa2326156dfed86a1de3&quot;,
#                 {
#                     center: [40.79822, -73.92550999999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb4bcb644452d3ae17ffd1f8bfd62762 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_cb4bcb644452d3ae17ffd1f8bfd62762.addTo(map_7942542a69a2fa2326156dfed86a1de3);
#
#             var marker_109c6acb8dce23d7f627c8131beba541 = L.marker(
#                 [40.78322, -73.96551],
#                 {}
#             ).addTo(map_7942542a69a2fa2326156dfed86a1de3);
#
#
#             var div_icon_5e7b09c86f31399648a2997ad2ceaac3 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg\n  xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\n  version=\&quot;1.1\&quot;\n  viewBox=\&quot;-20 -20 190 40\&quot;\n  stroke=\&quot;black\&quot;\n  fill=\&quot;hsl(0deg, 100%, 50%)\&quot;\n  stroke-width=\&quot;1\&quot;\n\u003e\n  \u003cpath d=\&quot;M 0 -1.5 l 0 3\nl 130 0 l 0 4.5\nl 20 -6 l -20 -6\nl 0 4.5 Z\&quot; /\u003e\n\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [20, 20], &quot;iconSize&quot;: [190, 40]});
#             marker_109c6acb8dce23d7f627c8131beba541.setIcon(div_icon_5e7b09c86f31399648a2997ad2ceaac3);
#
#
#             var marker_9d2e8d5f248411d60d296d1d223d52bb = L.marker(
#                 [40.78322, -73.92550999999999],
#                 {}
#             ).addTo(map_7942542a69a2fa2326156dfed86a1de3);
#
#
#             var div_icon_61cd7fffbc73a8babccfb2a83850d149 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg\n  xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\n  version=\&quot;1.1\&quot;\n  viewBox=\&quot;-20 -20 190 40\&quot;\n  stroke=\&quot;black\&quot;\n  fill=\&quot;hsl(0deg, 100%, 50%)\&quot;\n  stroke-width=\&quot;1\&quot;\n\u003e\n  \u003cpath d=\&quot;M 0 -1.5 l 0 3\nl 130 0 l 0 4.5\nl 20 -6 l -20 -6\nl 0 4.5 Z\&quot; /\u003e\n\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [170.0, 20.0], &quot;iconSize&quot;: [190, 40]});
#             marker_9d2e8d5f248411d60d296d1d223d52bb.setIcon(div_icon_61cd7fffbc73a8babccfb2a83850d149);
#
#
#             var marker_49171baa308853991b92ae656c1031b1 = L.marker(
#                 [40.78322, -73.90550999999999],
#                 {}
#             ).addTo(map_7942542a69a2fa2326156dfed86a1de3);
#
#
#             var div_icon_6523aebe6a3a277974b7826642e7d30c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg\n  xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\n  version=\&quot;1.1\&quot;\n  viewBox=\&quot;-20 -20 190 40\&quot;\n  stroke=\&quot;black\&quot;\n  fill=\&quot;hsl(0deg, 100%, 50%)\&quot;\n  stroke-width=\&quot;1\&quot;\n\u003e\n  \u003cpath d=\&quot;M 0 -1.5 l 0 3\nl 130 0 l 0 4.5\nl 20 -6 l -20 -6\nl 0 4.5 Z\&quot; /\u003e\n\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [95.0, 20.0], &quot;iconSize&quot;: [190, 40]});
#             marker_49171baa308853991b92ae656c1031b1.setIcon(div_icon_6523aebe6a3a277974b7826642e7d30c);
#
#
#             var marker_b25eadb59dbd97c59abd8229d5416364 = L.marker(
#                 [40.78422, -73.96551],
#                 {}
#             ).addTo(map_7942542a69a2fa2326156dfed86a1de3);
#
#
#             var div_icon_ea4d1bfd4d921272687aa6357dfc9bb8 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003csvg\n  xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\n  version=\&quot;1.1\&quot;\n  viewBox=\&quot;-20 -20 198 40\&quot;\n  stroke=\&quot;black\&quot;\n  fill=\&quot;hsl(10deg, 100%, 50%)\&quot;\n  stroke-width=\&quot;1\&quot;\n\u003e\n  \u003cpath d=\&quot;M 0 -1.5 l 0 3\nl 137.8217 0 l 0 4.5\nl 20 -6 l -20 -6\nl 0 4.5 Z\&quot; /\u003e\n\u003c/svg\u003e&quot;, &quot;iconAnchor&quot;: [20, 20], &quot;iconSize&quot;: [198, 40]});
#             marker_b25eadb59dbd97c59abd8229d5416364.setIcon(div_icon_ea4d1bfd4d921272687aa6357dfc9bb8);
#
#
#             var marker_cbed4d083860990dad61522178c376ca = L.marker(
#                 [40.78422, -73.92550999999999],
#                 {}
#             ).addTo(map_7942542a69a2fa2326156dfed86a1de3);
#
#
#             var div_icon_ab312d427512c54

# %% [markdown]
# ## Indices and tables
#
# * {ref}`genindex`
# * {ref}`modindex`
# * {ref}`search`
